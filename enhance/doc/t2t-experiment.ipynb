# %% [markdown]
# # [WIP] Running a single training experiment in batch with T2TExperiment

# %% [markdown]
# Working out an interface for launching individual training experiments that integrates well with an over-arching study running solution

# %%
import os
APP_ROOT="/home/jovyan/work/examples-enhance/enhance"
LAUNCHER_PATH = os.path.join(APP_ROOT, "py", "launcher.py")

# %%
# !python {LAUNCHER_PATH} --app_root {APP_ROOT} --mode train --batch \
    --problem allen_brain_img2img --hparams_set nonexistent
# Out:
# INFO:root:Parsed args: {'gcp_project': None, 'app_root': '/home/jovyan/work/examples-enhance/enhance', 'use_image': 'gcr.io/kubeflow-rl/common-base:0.0.1', 'batch': True, 'rebuild_base': False, 'volume_claim_id': 'nfs-1', 'namespace': 'kubeflow', 'mode': 'train', 'problem': 'allen_brain_img2img', 'hparams_set': 'nonexistent'}
# INFO:root:Staged app workdir to /mnt/nfs-1/studies/dev/enhance-download-0326-2334-901f/staging
# {'_batch': True,
#  '_command': ['t2t-trainer',
#               '--t2t_usr_dir',
#               '/mnt/nfs-1/studies/dev/enhance-download-0326-2334-901f/staging/py',
#               '--problem',
#               'allen_brain_img2img',
#               '--hparams_set',
#               'nonexistent'],
#  'apiVersion': 'batch/v1',
#  'kind': 'Job',
#  'metadata': {'name': 'enhance-download-0326-2334-901f',
#               'namespace': 'kubeflow'},
#  'spec': {'backoffLimit': 4,
#           'template': {'spec': {'containers': [{'args': ['t2t-trainer',
# ...

# %%
# !kubectl get pods -n
