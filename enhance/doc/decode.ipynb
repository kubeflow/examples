# %% [markdown]
# ## [WIP] Batch enhancement of raw images

# %%
import os
APP_ROOT="/home/jovyan/work/examples-enhance/enhance"
LAUNCHER_PATH = os.path.join(APP_ROOT, "py", "launcher.py")

# %% [markdown]
# ### Prepare the input images

# %%
# TODO: Describe uploading of input images to an input location, such as NFS or GCS

# %% [markdown]
# ### Run inference in batch

# %%
# Not implemented, for now just verifying the launcher interface

# %%
# !python {LAUNCHER_PATH} --app_root {APP_ROOT} --mode inference --batch
# Out:
# INFO:root:Parsed args: {'gcp_project': None, 'app_root': '/home/jovyan/work/examples-enhance/enhance', 'use_image': 'gcr.io/kubeflow-rl/common-base:0.0.1', 'batch': True, 'rebuild_base': False, 'volume_claim_id': 'nfs-1', 'namespace': 'kubeflow', 'mode': 'inference'}
# INFO:root:Staged app workdir to /mnt/nfs-1/studies/dev/enhance-download-0326-2352-08c3/staging
# {'_batch': True,
#  '_command': ['t2t-decoder',
#               '--t2t_usr_dir',
#               '/mnt/nfs-1/studies/dev/enhance-download-0326-2352-08c3/staging/py'],
#  'apiVersion': 'batch/v1',
#  'kind': 'Job',
#  'metadata': {'name': 'enhance-download-0326-2352-08c3',
#               'namespace': 'kubeflow'},
#  'spec': {'backoffLimit': 4,
#           'template': {'spec': {'containers': [{'args': ['t2t-decoder',
#                                                          '--t2t_usr_dir',
#                                                          '/mnt/nfs-1/studies/dev/enhance-download-0326-2352-08c3/staging/py'],
# ...
